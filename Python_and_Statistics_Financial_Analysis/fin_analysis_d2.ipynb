# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from path import Path

# %%
fb = pd.read_csv(Path("resources/data/facebook.csv"))
fb
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-12-31   20.400000   20.510000   19.990000   20.049999   19.459270
# 1    2015-01-02   20.129999   20.280001   19.809999   20.129999   19.536913
# 2    2015-01-05   20.129999   20.190001   19.700001   19.790001   19.206934
# 3    2015-01-06   19.820000   19.840000   19.170000   19.190001   18.624611
# 4    2015-01-07   19.330000   19.500000   19.080000   19.139999   18.576082
# ..          ...         ...         ...         ...         ...         ...
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume
# 0     4157500
# 1     2842000
# ...

# %%
fb["Price1"] = fb.Close.shift(-1)
fb
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-12-31   20.400000   20.510000   19.990000   20.049999   19.459270
# 1    2015-01-02   20.129999   20.280001   19.809999   20.129999   19.536913
# 2    2015-01-05   20.129999   20.190001   19.700001   19.790001   19.206934
# 3    2015-01-06   19.820000   19.840000   19.170000   19.190001   18.624611
# 4    2015-01-07   19.330000   19.500000   19.080000   19.139999   18.576082
# ..          ...         ...         ...         ...         ...         ...
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume      Price1
# 0     4157500   20.129999
# ...

# %%
fb["PriceDiff"] = fb.Price1 - fb.Close
fb
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-12-31   20.400000   20.510000   19.990000   20.049999   19.459270
# 1    2015-01-02   20.129999   20.280001   19.809999   20.129999   19.536913
# 2    2015-01-05   20.129999   20.190001   19.700001   19.790001   19.206934
# 3    2015-01-06   19.820000   19.840000   19.170000   19.190001   18.624611
# 4    2015-01-07   19.330000   19.500000   19.080000   19.139999   18.576082
# ..          ...         ...         ...         ...         ...         ...
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume      Price1  PriceDiff
# ...

# %%
fb["Returns_in_%"] = (fb.PriceDiff / fb.Close) * 100
fb
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-12-31   20.400000   20.510000   19.990000   20.049999   19.459270
# 1    2015-01-02   20.129999   20.280001   19.809999   20.129999   19.536913
# 2    2015-01-05   20.129999   20.190001   19.700001   19.790001   19.206934
# 3    2015-01-06   19.820000   19.840000   19.170000   19.190001   18.624611
# 4    2015-01-07   19.330000   19.500000   19.080000   19.139999   18.576082
# ..          ...         ...         ...         ...         ...         ...
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume      Price1  PriceDiff  Returns_in_%
# ...

# %%
fb["Direction"] = [1 if fb.loc[ei, "PriceDiff"]>0 else -1 for ei in fb.index]
fb["MA40"] = fb.Close.rolling(40).mean()
fb["MA200"] = fb.Close.rolling(200).mean()

# %%
fb.Close.plot()
fb.MA40.plot()
fb.MA200.plot()
# Out:
# <AxesSubplot:>

# %%
msft = pd.read_csv(Path("resources/data/microsoft.csv"))
msft
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763
# 1    2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731
# 2    2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068
# 3    2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783
# 4    2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817
# ..          ...        ...        ...        ...        ...        ...
# 775  2018-01-30  93.300003  93.660004  92.099998  92.739998  92.306389
# 776  2018-01-31  93.750000  95.400002  93.510002  95.010002  94.565781
# 777  2018-02-01  94.790001  96.070000  93.580002  94.260002  93.819290
# 778  2018-02-02  93.639999  93.970001  91.500000  91.779999  91.350883
# 779  2018-02-05  90.559998  93.239998  88.000000  88.000000  87.588554
#
#        Volume
# 0    21552500
# 1    27913900
# 2    39673900
# 3    36447900
# 4    29114100
# ..        ...
# ...

# %%
msft.Close.plot()
msft["MA10"] = msft.Close.rolling(40).mean().plot()
msft["MA50"] = msft.Close.rolling(200).mean().plot()

# %%
msft["Shares"] = [1 if msft.loc[ei, "MA10"] > msft.loc[ei,"MA50"] else 0 for ei in msft.index]
msft
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nv/0njw92cd71ddhz_hfr4fjqqm0000gn/T/ipykernel_23007/1694028718.py in <module>
# ----> 1 msft["Shares"] = [1 if msft.loc[ei, "MA10"]>msft.loc[ei,"MA50"] else 0 for ei in msft.index]
#       2 msft
#
# /var/folders/nv/0njw92cd71ddhz_hfr4fjqqm0000gn/T/ipykernel_23007/1694028718.py in <listcomp>(.0)
# ----> 1 msft["Shares"] = [1 if msft.loc[ei, "MA10"]>msft.loc[ei,"MA50"] else 0 for ei in msft.index]
#       2 msft
#
# TypeError: '>' not supported between instances of 'AxesSubplot' and 'AxesSubplot'

# %%
print(msft.iloc[0:1])
# Out:
#          Date   Open       High        Low      Close  Adj Close    Volume
# 0  2014-12-31  46.73  47.439999  46.450001  46.450001  42.848763  21552500

# %%
(fb.iloc[0:1])
# Out:
#          Date  Open   High    Low      Close  Adj Close   Volume     Price1
# 0  2014-12-31  20.4  20.51  19.99  20.049999   19.45927  4157500  20.129999

# %%
fb_close = fb["Close"]
fb_close
# Out:
# 0       20.049999
# 1       20.129999
# 2       19.790001
# 3       19.190001
# 4       19.139999
#           ...
# 775    242.720001
# 776    245.800003
# 777    240.500000
# 778    233.520004
# 779    213.699997
# Name: Close, Length: 780, dtype: float64
